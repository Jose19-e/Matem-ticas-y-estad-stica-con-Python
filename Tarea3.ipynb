# %% [markdown]
# # TAREA 3

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# EJERCICIO 1

# %%
#Comprobar gráficamente si las siguientes ecuaciones tienen solución.
print("""
3x + 2y = 6
6x + 4y = −9 """)

x = np.linspace(-10, 10)
y1 = (6 - 3*x) / 2
y2 = (-9 - 6*x) / 4

plt.plot(x, y1, label='3x + 2y = 6')
plt.plot(x, y2, label='6x + 4y = -9')
plt.title('Gráfica de las ecuaciones ¡SIN SOLUCIÓN!')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 3x + 2y = 6
# 6x + 4y = −9

# %%
x = np.linspace(-10, 10)
y1 = 3 - x
y2 = (1 - x) / 4

plt.plot(x, y1, label='x + y = 3')
plt.plot(x, y2, label='x - 4y = 1')
plt.title('Gráfica del sistema de ecuaciones ¡CON SOLUCION!')
plt.grid(True)
plt.legend()
plt.show()

# %%
A = np.array([[2, -1, 2], [2, 3, -1], [1, 2, 2]])
b = np.array([3, 0, -12])

solution = np.linalg.solve(A, b)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(solution[0], solution[1], solution[2], color='red', s=50, label='Punto de Intersección')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Punto de intersección del sistema de ecuaciones,¡CON SOLUCIÓN!')
ax.legend()

plt.show()

# %% [markdown]
# EJERCICIO 2

# %%
#2. Encuentra la ecuación de la recta tangente de la parábola y = x² + 3
x = np.linspace(0, 3)
y = x**2 + 3

x_punto = 1
y_punto = 4

m = 2 * x_punto
b = y_punto - pendiente * x_punto

recta_tangente = m * x + b

plt.plot(x, y, '-', color='blue', label='y = x^2 + 3')
plt.plot(x, recta_tangente, '.', color='red', label='Recta tangente')
plt.scatter(x_punto, y_punto, color='black', label='Punto (1,4)')
plt.title('Recta tangente en el punto (1,4)')
plt.legend()

plt.show()

# %% [markdown]
# EJERCICIO 3

# %%
x=np.linspace(0,3)
fig,ax=plt.subplots()
y=x**2+3
l1 = ax.plot(x,y,'-',color = 'blue')
ax.scatter(.5,0,color='red')
ax.grid(True)
indice=0
for i in x[0:-11]:
    m=2*i
    ax.plot(x,m*x-(m*x[indice])+y[indice],'-',color='orange')
    indice+=1
plt.title('No pude ajustar el slicing (VARIAS LINEAS)')
# Out:
# Text(0.5, 1.0, 'No pude ajustar el slicing (VARIAS LINEAS)')

# %% [markdown]
# EJERCICIO 4

# %%
def funcion(x):
    y = x**3 - x**2 -2*X
    return y

# %%
x = np.linspace(-1,6)
r = (funcion(3)-funcion(1))/(3-1)
print(r)
print(np.roots([3,-2,-9]))
fig,ax= plt.subplots()

y=x**3-x**2-2*x
l1=ax.plot(x,y,'-',color='green')
l2=ax.plot(x,7*x-9,'-',color='blue')
l3=ax.plot(x,7*x-15.05,'-',color='red')
# Out:
# [[9. 9. 9. ... 9. 9. 9.]
#  [9. 9. 9. ... 9. 9. 9.]
#  [9. 9. 9. ... 9. 9. 9.]
#  ...
#  [9. 9. 9. ... 9. 9. 9.]
#  [9. 9. 9. ... 9. 9. 9.]
#  [9. 9. 9. ... 9. 9. 9.]]
# [ 2.09716754 -1.43050087]
