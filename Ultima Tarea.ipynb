# %%
import csv
import matplotlib.pyplot as plt
import numpy as np 
import statistics as sts

# %% [markdown]
# EJERCICIO 1

# %%
arg1 = np.loadtxt("pesos.csv",delimiter=",",dtype=np.float32)
print(arg1)
# Out:
# [159. 136. 180. 129. 162. 150. 129. 146. 128. 178. 144. 167. 132. 172.
#  156. 178. 129. 142. 146. 159. 131. 135. 168. 152. 163. 145. 173. 147.
#  137. 143. 142. 133. 152. 166. 146. 131. 131. 160. 162. 146. 151. 179.
#  146. 142. 172. 175. 166. 137. 162. 159.]

# %%
#El valor más grande
print("Valor máximo",np.max(arg1))
#El valor más pequeño
print("Valor minimo",np.min(arg1))
#Obtuvieron 125(datos 1)o mas
O_125=np.where((arg1>=125),1,0).sum()
print(O_125)
#Obtuvieron 138 o menos
O_138=np.where((arg1<=138),1,0).sum()
print(O_138)
#Porcentaje de valores (129<=x>=146)
porcentaje=np.where((arg2>=129)&(arg2<=146),1,0).sum()/50
print(porcentaje)
print('% de estudiantes 129<=x<146',porcentaje*100,"%")
#ordenados
arg2=np.sort(np.reshape(arg1,50))
print(arg2)
#Frecuencias absolutas simples
variables,repetidas=np.unique(arg2,return_counts=True)
frecuencia_absolutas_simples=repetidas
print("Frecuencias abs simples",frecuencia_absolutas_simples)
#Frecuencias absolutas acumuladas
frecuencias_absolutas_acumuladas=np.cumsum(frecuencia_absolutas_simples)
print("Frecuencias abs acumuladas",frecuencias_absolutas_acumuladas)
#Frecuencias relativas simples
frecuencias_relativas_simple=np.round((frecuencia_absolutas_simples/50)*100,2)
print("frecuencias relativas simple",frecuencias_relativas_simple)
#Frecuencias relativas acumuladas
frecuencias_relativas_acumuladas=np.cumsum(frecuencias_relativas_simple)
print("frecuencias_relativas_acumuladas",frecuencias_relativas_acumuladas)
#Media aritmética de valores no agrupados
ma_agrupados=variables*repetidas
print("Media aritmética valores agrupados",np.sum(ma_agrupados)/50)
#Media Geométrica
media_g_agrupados=np.power(np.product(variables**repetidas),1/50)
print("Media Geometrica",media_g_agrupados)
#Media Armónica H
print("Media Armónica",sts.harmonic_mean(arg2))
#Mediana
print("Mediana: ",np.median(arg2))
#Moda
print("Moda: ",sts.mode(arg2))
#Múltiples Modas (si las hay)
print("Múltiples modas",sts.multimode(arg2))
print("-------------------------Cuartiles--------------------------")
#Cuartiles
print([round(q, 2) for q in sts.quantiles(arg2, n=4)])
print("---------------------------Deciles---------------------------")
#Deciles
print([round(q, 2) for q in sts.quantiles(arg2, n=10)])
print("------------------------percentiles-------------------------")
#percentiles
print([round(q, 2) for q in sts.quantiles(arg2, n=100)])
#HISTOGRAMA
fig, ax = plt.subplots(figsize=(14, 9))
b=np.append(variables,181)
frecuencias=ax.hist(arg2,bins=b,linewidth=.5,edgecolor="white")
ax.set(xlim=(127, 181), xticks=np.arange(128, 181,1),
       ylim=(1, 7), yticks=np.linspace(0, 6, 7,dtype=np.int16))
plt.xticks(fontsize=4)
ax.grid()
plt.show()
# Out:
# Valor máximo 180.0
# Valor minimo 128.0
# 50
# 13
# 0.46
# % de estudiantes 129<=x<146 46.0 %
# [128. 129. 129. 129. 131. 131. 131. 132. 133. 135. 136. 137. 137. 142.
#  142. 142. 143. 144. 145. 146. 146. 146. 146. 146. 147. 150. 151. 152.
#  152. 156. 159. 159. 159. 160. 162. 162. 162. 163. 166. 166. 167. 168.
#  172. 172. 173. 175. 178. 178. 179. 180.]
# Frecuencias abs simples [1 3 3 1 1 1 1 2 3 1 1 1 5 1 1 1 2 1 3 1 3 1 2 1 1 2 1 1 2 1 1]
# Frecuencias abs acumuladas [ 1  4  7  8  9 10 11 13 16 17 18 19 24 25 26 27 29 30 33 34 37 38 40 41
#  42 44 45 46 48 49 50]
# frecuencias relativas simple [ 2.  6.  6.  2.  2.  2.  2.  4.  6.  2.  2.  2. 10.  2.  2.  2.  4.  2.
#   6.  2.  6.  2.  4.  2.  2.  4.  2.  2.  4.  2.  2.]
# frecuencias_relativas_acumuladas [  2.   8.  14.  16.  18.  20.  22.  26.  32.  34.  36.  38.  48.  50.
#   52.  54.  58.  60.  66.  68.  74.  76.  80.  82.  84.  88.  90.  92.
#   96.  98. 100.]
# Media aritmética valores agrupados 151.48
# ...

# %% [markdown]
#     EJERCICIO 2

# %%
arg3 = np.loadtxt("tornillos.csv",delimiter=" ",dtype=np.float32)
print(arg3)
#El valor más grande
print("Valor máximo",np.max(arg3))
#El valor más pequeño
print("Valor minimo",np.min(arg3))
#Obtuvieron 1.25(datos 2) o mas
M_125=np.where((arg3>=1.25),1,0).sum()
print("Obtuvieron 1.25 o mas: ",M_125)
#Obtuvieron 1.32(datos 2) o menos
M_132=np.where((arg3<=1.32),1,0).sum()
print("Obtuvieron 1.32 o menos: ",M_132)
#Porcentaje de valores (1.39<x>=1.41, dato2)
porcentaje=np.where((arg4>=1.39)&(arg4<=1.41),1,0).sum()/50
print('% de estudiantes 1.39<=x<1.41',porcentaje*100,"%")
#ordenados
arg4=np.sort(np.reshape(arg3,50))
print(arg4)
#Frecuencias absolutas simples
variables,repetidas=np.unique(arg4,return_counts=True)
frecuencia_absolutas_simples=repetidas
print("Frecuencias abs simples",frecuencia_absolutas_simples)
#Frecuencias absolutas acumuladas
frecuencias_absolutas_acumuladas=np.cumsum(frecuencia_absolutas_simples)
print("Frecuencias abs acumuladas",frecuencias_absolutas_acumuladas)
#Frecuencias relativas simples
frecuencias_relativas_simple=np.round((frecuencia_absolutas_simples/50)*100,2)
print("frecuencias relativas simple",frecuencias_relativas_simple)
#Frecuencias relativas acumuladas
frecuencias_relativas_acumuladas=np.cumsum(frecuencias_relativas_simple)
print("frecuencias_relativas_acumuladas",frecuencias_relativas_acumuladas)
#Media aritmética de valores no agrupados
ma_agrupados=variables*repetidas
print("Media aritmética valores no agrupados",np.sum(ma_agrupados)/50)
#Media Geométrica
media_g_agrupados=np.power(np.product(variables**repetidas),1/50)
print("Media Geometrica",media_g_agrupados)
#Media Armónica H
print("Media Armónica",sts.harmonic_mean(arg4))
#Mediana
print("Mediana: ",np.median(arg4))
#Moda
print("Moda: ",sts.mode(arg4))
#Múltiples Modas (si las hay)
print("Múltiples modas",sts.multimode(arg4))
print("-------------------------Cuartiles--------------------------")
#Cuartiles
print([round(q, 2) for q in sts.quantiles(arg4, n=4)])
print("---------------------------Deciles---------------------------")
#Deciles
print([round(q, 2) for q in sts.quantiles(arg4, n=10)])
print("------------------------percentiles-------------------------")
#percentiles
print([round(q, 2) for q in sts.quantiles(arg4, n=100)])

#HISTOGRAMA
fig, ax = plt.subplots(figsize=(14, 9))
b=np.append(variables,1.7)
frecuencias=ax.hist(arg4,bins=b,linewidth=.5,edgecolor="white")
ax.set(xlim=(1.1, 1.7), xticks=np.arange(1.2, 1.7,.01),
       ylim=(1, 6), yticks=np.linspace(0, 5, 7,dtype=np.int16))
plt.xticks(fontsize=5)
ax.grid()
plt.show()
# Out:
# [1.34 1.2  1.41 1.52 1.49 1.3  1.24 1.29 1.53 1.55 1.37 1.56 1.56 1.39
#  1.39 1.51 1.59 1.54 1.29 1.44 1.5  1.22 1.32 1.42 1.42 1.6  1.58 1.31
#  1.45 1.29 1.51 1.4  1.29 1.57 1.24 1.44 1.28 1.52 1.49 1.41 1.32 1.31
#  1.23 1.25 1.57 1.53 1.35 1.57 1.5  1.49]
# Valor máximo 1.6
# Valor minimo 1.2
# Obtuvieron 1.25 o mas:  45
# Obtuvieron 1.32 o menos:  16
# % de estudiantes 1.39<=x<1.41 10.0 %
# [1.2  1.22 1.23 1.24 1.24 1.25 1.28 1.29 1.29 1.29 1.29 1.3  1.31 1.31
#  1.32 1.32 1.34 1.35 1.37 1.39 1.39 1.4  1.41 1.41 1.42 1.42 1.44 1.44
#  1.45 1.49 1.49 1.49 1.5  1.5  1.51 1.51 1.52 1.52 1.53 1.53 1.54 1.55
#  1.56 1.56 1.57 1.57 1.57 1.58 1.59 1.6 ]
# Frecuencias abs simples [1 1 1 2 1 1 4 1 2 2 1 1 1 2 1 2 2 2 1 3 2 2 2 2 1 1 2 3 1 1 1]
# Frecuencias abs acumuladas [ 1  2  3  5  6  7 11 12 14 16 17 18 19 21 22 24 26 28 29 32 34 36 38 40
#  41 42 44 47 48 49 50]
# frecuencias relativas simple [2. 2. 2. 4. 2. 2. 8. 2. 4. 4. 2. 2. 2. 4. 2. 4. 4. 4. 2. 6. 4. 4. 4. 4.
# ...
